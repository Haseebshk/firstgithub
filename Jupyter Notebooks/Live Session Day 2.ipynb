# %%
# BMI Calculator

# %%
Greetings= input("Hi, can you please tell me your name? ")
Greetings
Mass= input("can you please tell me your weight in kg? ") #here weight is same as mass
Mass= float(Mass)
Height=input("can you please tell me your height in meter? ")
Height= float(Height)
BMI= Mass/Height**2 # BMI= MASS in kg/ square of height in meters
Answer=(Greetings, "your BMI is", BMI)
Answer
# Out:
# Hi, can you please tell me your name? Haseeb
# can you please tell me your weight in kg? 70
# can you please tell me your height in meter? 1.72
# ('Haseeb', 'your BMI is', 23.661438615467823)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic=sns.load_dataset("titanic")
sns.catplot(x="sex", y="survived", hue="class", kind="bar", data=titanic)
plt.show()

# %%
# scatter plot
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic=sns.load_dataset("titanic")
g=sns.FacetGrid(titanic, row="sex", hue= "alone")
g=(g.map(plt.scatter, "age", "fare").add_legend())
plt.show()

# %%
print(titanic)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic=sns.load_dataset("titanic")
sns.catplot(x="alone", y="embark_town", hue="class", kind="bar", data=titanic)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)

titanic=sns.load_dataset("titanic")
sns.catplot(x="alone", y="embark_town", kind="bar", data=titanic)
plt.show()
